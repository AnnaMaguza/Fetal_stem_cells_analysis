# %% [markdown]
# ### Create anndata object from re-mapped E-MTAB-9536 samples
# - **Developed by:** Anna Maguza
# - **Affilation:** Faculty of Medicine, Würzburg University
# - **Creation date:** 23th of October 2024
# - **Last modified date:** 23th of October 2024

# %% [markdown]
# ### Import packages

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sci
import anndata as ad
from scipy import io,sparse
import os
import muon as mu
from datetime import datetime

# %% [markdown]
# + We want to save the spliced/unspliced counts in our anndata object

# %%
def starsolo_velocity_anndata(input_dir):
    """
    input directory should contain barcodes.tsv, features.tsv with 3 mtx from spliced, ambigious, unspliced
    """
    obs = pd.read_csv(os.path.join(input_dir,'barcodes.tsv'), header = None, index_col = 0)
    # Remove index column name to make it compliant with the anndata format
    obs.index.name = None

    var = pd.read_csv(os.path.join(input_dir,"features.tsv"), sep='\t',names = ('gene_ids', 'feature_types'), index_col = 1)
    var.index.name = None

    spliced=sci.sparse.csr_matrix(sci.io.mmread(os.path.join(input_dir,"spliced.mtx")).T)
    ambiguous=sci.sparse.csr_matrix(sci.io.mmread(os.path.join(input_dir,"ambiguous.mtx")).T)
    unspliced=sci.sparse.csr_matrix(sci.io.mmread(os.path.join(input_dir,"unspliced.mtx")).T)
    adata=ad.AnnData(X=spliced,obs=obs,var=var,layers={'spliced':spliced,"ambiguous":ambiguous,"unspliced":unspliced})
    adata.var_names_make_unique()
    return adata

# %% [markdown]
# + Upload sample description dataframe

# %%
samples = pd.read_csv("raw_fastq_files/Elmentaite_2021/metadata/E-MTAB-9536.sdrf.txt", sep = "\t")

# %% [markdown]
# + Base path for remapped samples

# %%
base_path = 'raw_data/Elmentaite_2021/remapped_fetal_data_E-MTAB-9536_starsolo'

# %%
ann_data_list = []
failed_samples = []

for sample_name in samples['Extract Name']:
    try:
        # Try loading the AnnData object from the UMI10_output path
        sample_path = f"{base_path}/{sample_name}/UMI10_output/Velocyto/raw"
        sample_name_adata = starsolo_velocity_anndata(sample_path)

        # Create the cell_id column
        sample_name_adata.obs['Extract Name'] = sample_name

        ann_data_list.append(sample_name_adata)
    except FileNotFoundError:
        try:
            # If not found in UMI10_output, try loading from the UMI12_output path
            sample_path = f"{base_path}/{sample_name}/UMI12_output/Velocyto/raw"
            sample_name_adata = starsolo_velocity_anndata(sample_path)

            # Create the cell_id column
            sample_name_adata.obs['Extract Name'] = sample_name

            ann_data_list.append(sample_name_adata)
        except FileNotFoundError:
            # If sample is not found in either path, add it to the failed_samples list
            failed_samples.append(sample_name)
            print(f"Sample {sample_name} not found in both UMI10 and UMI12 paths, skipping.")

# Merge all AnnData objects into one, if there are any
if ann_data_list:
    combined_adata = ann_data_list[0].concatenate(ann_data_list[1:], join='outer')
else:
    combined_adata = None
    print("No valid AnnData objects found to merge.")

# List samples that were not processed
if failed_samples:
    print("The following samples were not processed:")
    for sample in failed_samples:
        print(sample)
# Out:
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/utils.py:260: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /tmp/ipykernel_228900/3658790609.py:31: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   combined_adata = ann_data_list[0].concatenate(ann_data_list[1:], join='outer')

# %%
combined_adata.obs['barcode'] = combined_adata.obs.index.copy()

# %%
combined_adata.obs = combined_adata.obs.merge(samples, on='Extract Name', how='left', suffixes=('', '_y'))

combined_adata.obs = combined_adata.obs.loc[:, ~combined_adata.obs.columns.str.endswith('_y')]

# %%
combined_adata.obs.index = combined_adata.obs['barcode']

# %%
combined_adata.obs
# Out:
#                                Extract Name batch              barcode  \
# barcode
# AAACCTGAGAAACCAT-0           FCA_gut8015060     0   AAACCTGAGAAACCAT-0
# AAACCTGAGAAACCGC-0           FCA_gut8015060     0   AAACCTGAGAAACCGC-0
# AAACCTGAGAAACCTA-0           FCA_gut8015060     0   AAACCTGAGAAACCTA-0
# AAACCTGAGAAACGAG-0           FCA_gut8015060     0   AAACCTGAGAAACGAG-0
# AAACCTGAGAAACGCC-0           FCA_gut8015060     0   AAACCTGAGAAACGCC-0
# ...                                     ...   ...                  ...
# TTTGTCATCTTTACAC-20  Human_colon_16S8159189    20  TTTGTCATCTTTACAC-20
# TTTGTCATCTTTACGT-20  Human_colon_16S8159189    20  TTTGTCATCTTTACGT-20
# TTTGTCATCTTTAGGG-20  Human_colon_16S8159189    20  TTTGTCATCTTTAGGG-20
# TTTGTCATCTTTAGTC-20  Human_colon_16S8159189    20  TTTGTCATCTTTAGTC-20
# TTTGTCATCTTTCCTC-20  Human_colon_16S8159189    20  TTTGTCATCTTTCCTC-20
#
#                                 Source Name Comment[ENA_SAMPLE]  \
# barcode
# AAACCTGAGAAACCAT-0           FCA_gut8015060          ERS5054877
# AAACCTGAGAAACCGC-0           FCA_gut8015060          ERS5054877
# AAACCTGAGAAACCTA-0           FCA_gut8015060          ERS5054877
# AAACCTGAGAAACGAG-0           FCA_gut8015060          ERS5054877
# AAACCTGAGAAACGCC-0           FCA_gut8015060          ERS5054877
# ...                                     ...                 ...
# TTTGTCATCTTTACAC-20  Human_colon_16S8159189          ERS5054897
# TTTGTCATCTTTACGT-20  Human_colon_16S8159189          ERS5054897
# TTTGTCATCTTTAGGG-20  Human_colon_16S8159189          ERS5054897
# TTTGTCATCTTTAGTC-20  Human_colon_16S8159189          ERS5054897
# TTTGTCATCTTTCCTC-20  Human_colon_16S8159189          ERS5054897
#
#                     Comment[BioSD_SAMPLE] Characteristics[organism]  \
# barcode
# AAACCTGAGAAACCAT-0           SAMEA7296311              Homo sapiens
# AAACCTGAGAAACCGC-0           SAMEA7296311              Homo sapiens
# AAACCTGAGAAACCTA-0           SAMEA7296311              Homo sapiens
# AAACCTGAGAAACGAG-0           SAMEA7296311              Homo sapiens
# AAACCTGAGAAACGCC-0           SAMEA7296311              Homo sapiens
# ...                                   ...                       ...
# TTTGTCATCTTTACAC-20          SAMEA7296331              Homo sapiens
# TTTGTCATCTTTACGT-20          SAMEA7296331              Homo sapiens
# TTTGTCATCTTTAGGG-20          SAMEA7296331              Homo sapiens
# TTTGTCATCTTTAGTC-20          SAMEA7296331              Homo sapiens
# TTTGTCATCTTTCCTC-20          SAMEA7296331              Homo sapiens
#
#                      Characteristics[age] Unit[time unit] Term Source REF  \
# barcode
# AAACCTGAGAAACCAT-0                     17            week             EFO
# AAACCTGAGAAACCGC-0                     17            week             EFO
# AAACCTGAGAAACCTA-0                     17            week             EFO
# AAACCTGAGAAACGAG-0                     17            week             EFO
# AAACCTGAGAAACGCC-0                     17            week             EFO
# ...                                   ...             ...             ...
# TTTGTCATCTTTACAC-20                    15            week             EFO
# TTTGTCATCTTTACGT-20                    15            week             EFO
# TTTGTCATCTTTAGGG-20                    15            week             EFO
# TTTGTCATCTTTAGTC-20                    15            week             EFO
# TTTGTCATCTTTCCTC-20                    15            week             EFO
#
#                      ... Comment[ENA_RUN]  \
# barcode              ...
# AAACCTGAGAAACCAT-0   ...       ERR4574279
# AAACCTGAGAAACCGC-0   ...       ERR4574279
# AAACCTGAGAAACCTA-0   ...       ERR4574279
# AAACCTGAGAAACGAG-0   ...       ERR4574279
# AAACCTGAGAAACGCC-0   ...       ERR4574279
# ...                  ...              ...
# TTTGTCATCTTTACAC-20  ...       ERR4574299
# TTTGTCATCTTTACGT-20  ...       ERR4574299
# TTTGTCATCTTTAGGG-20  ...       ERR4574299
# TTTGTCATCTTTAGTC-20  ...       ERR4574299
# TTTGTCATCTTTCCTC-20  ...       ERR4574299
#
#                                                       Comment[BAM_URI]  \
# barcode
# AAACCTGAGAAACCAT-0   ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
# AAACCTGAGAAACCGC-0   ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
# AAACCTGAGAAACCTA-0   ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
# AAACCTGAGAAACGAG-0   ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
# AAACCTGAGAAACGCC-0   ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
# ...                                                                ...
# TTTGTCATCTTTACAC-20  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
# TTTGTCATCTTTACGT-20  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
# TTTGTCATCTTTAGGG-20  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
# TTTGTCATCTTTAGTC-20  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
# TTTGTCATCTTTCCTC-20  ftp://ftp.sra.ebi.ac.uk/vol1/run/ERR457/ERR457...
#
#                                                 Comment[read1 file]  \
# barcode
# AAACCTGAGAAACCAT-0           FCA_gut8015060_S1_L001_R1_001.fastq.gz
# AAACCTGAGAAACCGC-0           FCA_gut8015060_S1_L001_R1_001.fastq.gz
# AAACCTGAGAAACCTA-0           FCA_gut8015060_S1_L001_R1_001.fastq.gz
# AAACCTGAGAAACGAG-0           FCA_gut8015060_S1_L001_R1_001.fastq.gz
# AAACCTGAGAAACGCC-0           FCA_gut8015060_S1_L001_R1_001.fastq.gz
# ...                                                             ...
# TTTGTCATCTTTACAC-20  Human_colon_16S8159189_S1_L001_R1_001.fastq.gz
# TTTGTCATCTTTACGT-20  Human_colon_16S8159189_S1_L001_R1_001.fastq.gz
# TTTGTCATCTTTAGGG-20  Human_colon_16S8159189_S1_L001_R1_001.fastq.gz
# TTTGTCATCTTTAGTC-20  Human_colon_16S8159189_S1_L001_R1_001.fastq.gz
# TTTGTCATCTTTCCTC-20  Human_colon_16S8159189_S1_L001_R1_001.fastq.gz
#
#                                                     Comment[FASTQ_URI]  \
# barcode
# AAACCTGAGAAACCAT-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCGC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCTA-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGAG-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGCC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# ...                                                                ...
# TTTGTCATCTTTACAC-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTACGT-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGGG-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGTC-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTCCTC-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#                                                 Comment[read2 file]  \
# barcode
# AAACCTGAGAAACCAT-0           FCA_gut8015060_S1_L001_R2_001.fastq.gz
# AAACCTGAGAAACCGC-0           FCA_gut8015060_S1_L001_R2_001.fastq.gz
# AAACCTGAGAAACCTA-0           FCA_gut8015060_S1_L001_R2_001.fastq.gz
# AAACCTGAGAAACGAG-0           FCA_gut8015060_S1_L001_R2_001.fastq.gz
# AAACCTGAGAAACGCC-0           FCA_gut8015060_S1_L001_R2_001.fastq.gz
# ...                                                             ...
# TTTGTCATCTTTACAC-20  Human_colon_16S8159189_S1_L001_R2_001.fastq.gz
# TTTGTCATCTTTACGT-20  Human_colon_16S8159189_S1_L001_R2_001.fastq.gz
# TTTGTCATCTTTAGGG-20  Human_colon_16S8159189_S1_L001_R2_001.fastq.gz
# TTTGTCATCTTTAGTC-20  Human_colon_16S8159189_S1_L001_R2_001.fastq.gz
# TTTGTCATCTTTCCTC-20  Human_colon_16S8159189_S1_L001_R2_001.fastq.gz
#
#                                                    Comment[FASTQ_URI2]  \
# barcode
# AAACCTGAGAAACCAT-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCGC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCTA-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGAG-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGCC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# ...                                                                ...
# TTTGTCATCTTTACAC-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTACGT-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGGG-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGTC-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTCCTC-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#                                                Comment[index1 file]  \
# barcode
# AAACCTGAGAAACCAT-0           FCA_gut8015060_S1_L001_I1_001.fastq.gz
# AAACCTGAGAAACCGC-0           FCA_gut8015060_S1_L001_I1_001.fastq.gz
# AAACCTGAGAAACCTA-0           FCA_gut8015060_S1_L001_I1_001.fastq.gz
# AAACCTGAGAAACGAG-0           FCA_gut8015060_S1_L001_I1_001.fastq.gz
# AAACCTGAGAAACGCC-0           FCA_gut8015060_S1_L001_I1_001.fastq.gz
# ...                                                             ...
# TTTGTCATCTTTACAC-20  Human_colon_16S8159189_S1_L001_I1_001.fastq.gz
# TTTGTCATCTTTACGT-20  Human_colon_16S8159189_S1_L001_I1_001.fastq.gz
# TTTGTCATCTTTAGGG-20  Human_colon_16S8159189_S1_L001_I1_001.fastq.gz
# TTTGTCATCTTTAGTC-20  Human_colon_16S8159189_S1_L001_I1_001.fastq.gz
# TTTGTCATCTTTCCTC-20  Human_colon_16S8159189_S1_L001_I1_001.fastq.gz
#
#                                                    Comment[FASTQ_URI3]  \
# barcode
# AAACCTGAGAAACCAT-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCGC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCTA-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGAG-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGCC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# ...                                                                ...
# TTTGTCATCTTTACAC-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTACGT-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGGG-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGTC-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTCCTC-20  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#                     Factor Value[organism part] Factor Value[sampling site]
# barcode
# AAACCTGAGAAACCAT-0              large intestine
# AAACCTGAGAAACCGC-0              large intestine
# AAACCTGAGAAACCTA-0              large intestine
# AAACCTGAGAAACGAG-0              large intestine
# AAACCTGAGAAACGCC-0              large intestine
# ...                                         ...                         ...
# TTTGTCATCTTTACAC-20                       ileum                    terminal
# TTTGTCATCTTTACGT-20                       ileum                    terminal
# TTTGTCATCTTTAGGG-20                       ileum                    terminal
# TTTGTCATCTTTAGTC-20                       ileum                    terminal
# TTTGTCATCTTTCCTC-20                       ileum                    terminal
#
# [15482880 rows x 66 columns]

# %%
project = 'gut'
species = 'hs'
atribute = 'Elementaite2021_E-MTAB-9536'
name = 'AM'
timestamp = datetime.now().strftime('%d%m%Y_%H%M%S')
counts = 'raw'

combined_adata.uns['processing_history'] = []
combined_adata.uns['processing_history']={
    'timestamp': timestamp,
    'step': 'create raw anndata after mapping, no filtering'}


combined_adata.write_h5ad(f"raw_data/Elmentaite_2021/{project}_{species}_{atribute}_{name}_{timestamp}_{counts}.h5ad")

# %%
adata = sc.read_h5ad(f"raw_data/Elmentaite_2021/{project}_{species}_{atribute}_{name}_{timestamp}_{counts}.h5ad")

# %%
mdata = mu.MuData({'rna': combined_adata})
mdata.write(f"raw_data/Elmentaite_2021/{project}_{species}_{atribute}_{name}_{timestamp}_{counts}.h5mu")
# Out:
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
