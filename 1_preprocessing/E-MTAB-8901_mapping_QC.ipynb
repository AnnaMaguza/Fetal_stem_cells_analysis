# %% [markdown]
# #### Analyze the mapping quality of E-MTAB-8901
# - **Developed by:** Anna Maguza
# - **Affilation:** Faculty of Medicine, Würzburg University
# - **Created date:** 23th October 2024
# - **Last modified dte:** 23th October 2024
#
# This notebook is created to check the quality of the mapping from E-MTAB-8901 study. In this notebook we are visualizing `StarSolo` mapping metrics.

# %% [markdown]
# + Import packages

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# + Some samples had UMI length 12, and some ten, therefore the mapping script tried both options, and ended up in generation of two Log.progress.out files but one is empty. The following function indents to choose the correct file by analyzing file size.

# %%
def get_log_file(sample_dir):
    umi10_log = os.path.join(sample_dir, "UMI10_Log.progress.out")
    umi12_log = os.path.join(sample_dir, "UMI12_Log.progress.out")
    
    if os.path.exists(umi12_log) and os.path.getsize(umi12_log) > 1000:
        return umi12_log
    elif os.path.exists(umi10_log) and os.path.getsize(umi10_log) > 1000:
        return umi10_log
    else:
        return None

# %% [markdown]
# + Transform Log.progress.out file to dataframe

# %%
def process_sample(sample_dir):
    log_file = get_log_file(sample_dir)
    if log_file is None:
        print(f"Warning: No valid mapping log found for sample {os.path.basename(sample_dir)}")
        return None
    
    try:
        # Read the file, skipping the header rows
        df = pd.read_csv(log_file, sep='\s+', skiprows=2,
                        names=['Month', 'Day', 'Time', 'Speed', 'Number', 'Length', 
                              'Mapped_unique', 'Mapped_length', 'Mapped_MMrate', 
                              'Mapped_multi', 'Unmapped_multi+', 'Unmapped_MM', 
                              'Unmapped_short', 'Unmapped_other'])
        
        # Convert percentage columns to float
        percentage_columns = ['Mapped_unique', 'Mapped_MMrate', 'Mapped_multi',
                            'Unmapped_multi+', 'Unmapped_MM', 'Unmapped_short', 
                            'Unmapped_other']
        
        for col in percentage_columns:
            df[col] = df[col].str.rstrip('%').astype('float') / 100.0
        
        # Convert numeric columns
        df['Mapped_length'] = pd.to_numeric(df['Mapped_length'])
        
        # Calculate means for the metrics of interest
        metrics_of_interest = ['Mapped_unique', 'Mapped_length', 'Mapped_MMrate',
                             'Mapped_multi', 'Unmapped_multi+', 'Unmapped_MM',
                             'Unmapped_short', 'Unmapped_other']
        
        mean_values = df[metrics_of_interest].mean()
        return mean_values
        
    except Exception as e:
        print(f"Error processing {log_file}: {str(e)}")
        return None

# %%
BASE_DIR = "raw_data/Elmentaite_2021/remapped_fetal_data_E-MTAB-8901_starsolo"

# %%
sample_dirs = glob.glob(os.path.join(BASE_DIR, "*"))
results = {}
for sample_dir in sample_dirs:
    sample_name = os.path.basename(sample_dir)
    print(f"Processing sample: {sample_name}")
        
    mean_values = process_sample(sample_dir)
    if mean_values is not None:
        results[sample_name] = mean_values
# Out:
# Processing sample: 4918STDY7274839
# Processing sample: 4918STDY7718977
# Processing sample: 4918STDY7421298
# Processing sample: 4918STDY7317585
# Processing sample: 4918STDY7426911
# Warning: No valid mapping log found for sample 4918STDY7426911
# Processing sample: 4918STDY8366756
# Processing sample: 4918STDY7718972
# Processing sample: 4918STDY7693762
# Processing sample: 4918STDY7718976
# Processing sample: 4918STDY7717788
# Processing sample: 4918STDY7273965
# Processing sample: 4918STDY7901096
# Processing sample: 4918STDY7693760
# Processing sample: 4918STDY8366754
# Processing sample: 4918STDY7321515
# Processing sample: 4918STDY7426907
# Warning: No valid mapping log found for sample 4918STDY7426907
# Processing sample: 4918STDY7590324
# Processing sample: 4918STDY7962470
# Processing sample: 4918STDY7693759
# Processing sample: 4918STDY7693763
# Processing sample: 4918STDY7426908
# Warning: No valid mapping log found for sample 4918STDY7426908
# Processing sample: 4918STDY7702680
# Processing sample: mapping_metrics_summary.csv
# Warning: No valid mapping log found for sample mapping_metrics_summary.csv
# Processing sample: 4918STDY7426906
# Warning: No valid mapping log found for sample 4918STDY7426906
# Processing sample: 4918STDY7718974
# Processing sample: 4918STDY7923744
# Processing sample: 4918STDY7718973
# Processing sample: 4918STDY7717784
# Processing sample: 4918STDY7590325
# Processing sample: 4918STDY7273964
# Processing sample: 4918STDY7421297
# Warning: No valid mapping log found for sample 4918STDY7421297
# Processing sample: 4918STDY7317586
# Processing sample: 4918STDY7317587
# Processing sample: 4918STDY7421299
# Processing sample: E-MTAB-8901_raw_velocity_anndata.h5ad
# Warning: No valid mapping log found for sample E-MTAB-8901_raw_velocity_anndata.h5ad
# Processing sample: 4918STDY7982703
# Processing sample: 4918STDY7389431
# Processing sample: 4918STDY7426905
# Warning: No valid mapping log found for sample 4918STDY7426905
# Processing sample: 4918STDY7718975
# Processing sample: 4918STDY7933270
# Processing sample: 4918STDY7426909
# Warning: No valid mapping log found for sample 4918STDY7426909
# Processing sample: 4918STDY7717785
# Processing sample: 4918STDY7717783
# Processing sample: 4918STDY7717789
# Processing sample: 4918STDY7333456
# Processing sample: 4918STDY7982702
# Processing sample: 4918STDY7693757
# Processing sample: 4918STDY7844898
# Processing sample: 4918STDY7426904
# Warning: No valid mapping log found for sample 4918STDY7426904
# Processing sample: 4918STDY7717787
# Processing sample: 4918STDY7321514
# Processing sample: 4918STDY7844899
# Processing sample: 4918STDY7693761
# Processing sample: 4918STDY7693758
# Processing sample: 4918STDY7321513
# Processing sample: 4918STDY7426910
# Warning: No valid mapping log found for sample 4918STDY7426910
# Processing sample: 4918STDY7447825

# %%
results_df = pd.DataFrame(results).T

# %%
results_df
# Out:
#                  Mapped_unique  Mapped_length  Mapped_MMrate  Mapped_multi  \
# 4918STDY7274839       0.780333      95.400000       0.007095      0.132714
# 4918STDY7718977       0.146725      95.900000       0.005818      0.029176
# 4918STDY7421298       0.799500      96.700000       0.004875      0.166000
# 4918STDY7317585       0.765000      95.904762       0.005000      0.145571
# 4918STDY8366756       0.803571      94.100000       0.003857      0.150429
# 4918STDY7718972       0.156341      96.332143       0.006786      0.029114
# 4918STDY7693762       0.800682      96.900000       0.006000      0.155227
# 4918STDY7718976       0.167113      95.700000       0.007278      0.036113
# 4918STDY7717788       0.799591      95.886364       0.005500      0.152773
# 4918STDY7273965       0.751889      92.501587       0.008968      0.159540
# 4918STDY7901096       0.785583     137.893750       0.010958      0.122854
# 4918STDY7693760       0.789545      96.800000       0.005045      0.168182
# 4918STDY8366754       0.788000      94.100000       0.004000      0.164571
# 4918STDY7321515       0.750333      95.428571       0.005857      0.142000
# 4918STDY7590324       0.795300      95.990000       0.005800      0.160100
# 4918STDY7962470       0.795091      93.800000       0.009864      0.139955
# 4918STDY7693759       0.802696      96.600000       0.005000      0.148652
# 4918STDY7693763       0.810043      96.900000       0.005870      0.146000
# 4918STDY7702680       0.781273      96.200000       0.007091      0.171727
# 4918STDY7718974       0.202455      96.300000       0.007275      0.037576
# 4918STDY7923744       0.705710      93.438710       0.029097      0.160774
# 4918STDY7718973       0.143400      96.000000       0.008444      0.029689
# 4918STDY7717784       0.782500      95.700000       0.006900      0.161700
# 4918STDY7590325       0.797700      96.500000       0.005900      0.160000
# 4918STDY7273964       0.761284      92.802703       0.008014      0.149365
# 4918STDY7317586       0.778810      96.400000       0.004000      0.146000
# 4918STDY7317587       0.708100      95.905000       0.006000      0.139500
# 4918STDY7421299       0.813857      96.900000       0.005000      0.147000
# 4918STDY7982703       0.751909      94.354545       0.013045      0.153727
# 4918STDY7389431       0.815571      96.000000       0.005905      0.130000
# 4918STDY7718975       0.150667      96.300000       0.007200      0.033188
# 4918STDY7933270       0.791500      93.810000       0.007450      0.159900
# 4918STDY7717785       0.793810      95.409524       0.006000      0.148810
# 4918STDY7717783       0.773350      95.200000       0.005850      0.167600
# 4918STDY7717789       0.800857      95.795238       0.006857      0.147000
# 4918STDY7333456       0.799550      96.400000       0.006500      0.155250
# 4918STDY7982702       0.726864      93.800000       0.012682      0.140682
# 4918STDY7693757       0.764773      96.700000       0.007045      0.179818
# 4918STDY7844898       0.792300      94.100000       0.004000      0.177000
# 4918STDY7717787       0.793900      95.500000       0.006800      0.150400
# 4918STDY7321514       0.762000      95.500000       0.006318      0.138000
# 4918STDY7844899       0.793800      93.920000       0.004000      0.174000
# 4918STDY7693761       0.790818      96.609091       0.006045      0.158000
# 4918STDY7693758       0.796783      96.804348       0.004304      0.161130
# 4918STDY7321513       0.753300      95.700000       0.006000      0.135000
# 4918STDY7447825       0.808250      96.500000       0.003875      0.158375
#
#                  Unmapped_multi+  Unmapped_MM  Unmapped_short  Unmapped_other
# 4918STDY7274839         0.002000          0.0        0.068048        0.016905
# 4918STDY7718977         0.000275          0.0        0.772745        0.051020
# 4918STDY7421298         0.001000          0.0        0.029125        0.005000
# 4918STDY7317585         0.008000          0.0        0.072238        0.009000
# 4918STDY8366756         0.001000          0.0        0.037857        0.007000
# 4918STDY7718972         0.000386          0.0        0.753250        0.060909
# 4918STDY7693762         0.002000          0.0        0.038182        0.004000
# 4918STDY7718976         0.000170          0.0        0.752094        0.044453
# 4918STDY7717788         0.002000          0.0        0.039682        0.006000
# 4918STDY7273965         0.003857          0.0        0.078556        0.006397
# 4918STDY7901096         0.001000          0.0        0.087438        0.003000
# 4918STDY7693760         0.001000          0.0        0.036045        0.005000
# 4918STDY8366754         0.001000          0.0        0.040714        0.006000
# 4918STDY7321515         0.005000          0.0        0.087381        0.015667
# 4918STDY7590324         0.001000          0.0        0.036700        0.007000
# 4918STDY7962470         0.001000          0.0        0.057318        0.006000
# 4918STDY7693759         0.002000          0.0        0.041783        0.005000
# 4918STDY7693763         0.002000          0.0        0.038435        0.004000
# 4918STDY7702680         0.001000          0.0        0.039273        0.006000
# 4918STDY7718974         0.000652          0.0        0.702288        0.057152
# 4918STDY7923744         0.001000          0.0        0.126129        0.006484
# 4918STDY7718973         0.000311          0.0        0.770556        0.056067
# 4918STDY7717784         0.002000          0.0        0.049100        0.005000
# 4918STDY7590325         0.001000          0.0        0.035400        0.006000
# 4918STDY7273964         0.003784          0.0        0.078486        0.007041
# 4918STDY7317586         0.008000          0.0        0.059714        0.007571
# 4918STDY7317587         0.012650          0.0        0.127300        0.012950
# 4918STDY7421299         0.001000          0.0        0.033429        0.004000
# 4918STDY7982703         0.001000          0.0        0.086136        0.007000
# 4918STDY7389431         0.001000          0.0        0.045286        0.007429
# 4918STDY7718975         0.000021          0.0        0.778958        0.036979
# 4918STDY7933270         0.001000          0.0        0.041050        0.006950
# 4918STDY7717785         0.002000          0.0        0.044429        0.011000
# 4918STDY7717783         0.002000          0.0        0.052000        0.005500
# 4918STDY7717789         0.002000          0.0        0.044286        0.006000
# 4918STDY7333456         0.002000          0.0        0.039950        0.003000
# 4918STDY7982702         0.001000          0.0        0.089409        0.041727
# 4918STDY7693757         0.001000          0.0        0.049000        0.005227
# 4918STDY7844898         0.001000          0.0        0.024600        0.005000
# 4918STDY7717787         0.002000          0.0        0.048600        0.005000
# 4918STDY7321514         0.005000          0.0        0.082773        0.012045
# 4918STDY7844899         0.002000          0.0        0.025400        0.005000
# 4918STDY7693761         0.001000          0.0        0.045227        0.004000
# 4918STDY7693758         0.001130          0.0        0.035217        0.005000
# 4918STDY7321513         0.005000          0.0        0.092950        0.014000
# 4918STDY7447825         0.001000          0.0        0.024167        0.008000

# %%
output_file = os.path.join(BASE_DIR, "mapping_metrics_summary.csv")
results_df.to_csv(output_file)

# %%
results_df['Mapped_unique'].plot(kind='bar', figsize=(15, 7), title='Mapped Unique')
plt.xlabel('Sample')
plt.ylabel('Mapped Unique')
plt.xticks(rotation=90)
plt.show()
