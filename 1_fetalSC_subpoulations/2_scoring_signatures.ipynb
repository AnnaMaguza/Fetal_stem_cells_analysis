# %% [markdown]
# # Scoring Fetal Stem Cells signatures
#
# **Developed by:** Anna Maguza\
# **Affiliation:** Faculty of Medicine, Würzburg University\
# **Creation date:** 17th March 2025\
# **Last modified date:** 17th March 2025

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import scanpy as sc
import anndata
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import json
from datetime import datetime

# %%
timestamp = datetime.now().strftime('%d%m%Y_%H%M%S')

# %% [markdown]
# ## Upload data

# %%
adata = sc.read_h5ad('/Users/annamaguza/Desktop/data/gut_data/gut_hs_fetalSC_AM_05032025_150941_raw.h5ad')
adata

# %%
sc.pp.normalize_total(adata, target_sum=1e6, exclude_highly_expressed=True)
sc.pp.log1p(adata)

# %% [markdown]
# ## Score epithelial signatures

# %% [markdown]
# + Stem cells

# %%
sc.tl.score_genes(adata, ['LGR5', 'OLFM4', 'ASCL2', 'SMOC2', 'SOX9', 'AXIN2', 'RNF43', 'MSI1', 'PROM1', 'LRIG1', 'BMI1'], score_name='stem_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['LGR5', 'OLFM4', 'ASCL2', 'SMOC2', 'SOX9', 'AXIN2', 'RNF43', 'MSI1', 'PROM1', 'LRIG1', 'BMI1', 'stem_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_stem_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# * TA

# %%
sc.tl.score_genes(adata, ['MKI67', 'PCNA', 'TOP2A', 'CCNB1', 'CDK1', 'MCM2', 'TERT', 'CCNA2', 'CCNE1', 'CDC6'], score_name='ta_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['MKI67', 'PCNA', 'TOP2A', 'CCNB1', 'CDK1', 'MCM2', 'TERT', 'CCNA2', 'CCNE1', 'CDC6', 'ta_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_ta_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# * Enterocytes

# %%
sc.tl.score_genes(adata, ['VIL1', 'ALPI', 'SI', 'SLC2A5', 'FABP1', 'APOA1', 'APOA4', 'LCT', 'KRT20', 'ANPEP', 'MGAM', 'DPP4', 'ACE2'], score_name='Enterocytes_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['VIL1', 'ALPI', 'SI', 'SLC2A5', 'FABP1', 'APOA1', 'APOA4', 'LCT', 'KRT20', 'ANPEP', 'MGAM', 'DPP4', 'ACE2', 'Enterocytes_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_enterocytes_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# * Colonocytes

# %%
sc.tl.score_genes(adata, ['CA2', 'AQP8', 'CAR1', 'MS4A12', 'SLC26A3', 'GUCA2A', 'GUCA2B', 'BEST4', 'CLCA4', 'CA4', 'CA1', 'CEACAM7', 'TMPRSS2'], score_name='Colonocytes_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['CA2', 'AQP8', 'MS4A12', 'SLC26A3', 'GUCA2A', 'GUCA2B', 'BEST4', 'CLCA4', 'CA4', 'CA1', 'CEACAM7', 'TMPRSS2', 'Enterocytes_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_Colonocytes_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# * Goblet

# %%
sc.tl.score_genes(adata, ['MUC2', 'TFF3', 'SPINK4', 'FCGBP', 'CLCA1', 'AGR2', 'ZG16', 'RETNLB', 'SPDEF', 'ATOH1', 'GFI1', 'SIAT4C', 'ITLN1', 'FFAR4'], score_name='goblet_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['MUC2', 'TFF3', 'SPINK4', 'FCGBP', 'CLCA1', 'AGR2', 'ZG16', 'RETNLB', 'SPDEF', 'ATOH1', 'GFI1', 'ITLN1', 'FFAR4', 'goblet_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_goblet_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# * Paneth

# %%
sc.tl.score_genes(adata, ['LYZ', 'DEFA5', 'DEFA6', 'REG3A', 'PLA2G2A', 'NOD2', 'DLL4', 'EphB3', 'MMP7', 'PRSS2', 'ITLN2', 'REG3G', 'LEAP2'], score_name='Paneth_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['LYZ', 'DEFA5', 'REG3A', 'PLA2G2A', 'NOD2', 'DLL4', 'MMP7', 'PRSS2', 'ITLN2', 'REG3G', 'LEAP2', 'Paneth_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_Paneth_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# * EECs

# %%
sc.tl.score_genes(adata, ['CHGA', 'CHGB', 'SYP', 'NEUROD1', 'INSM1', 'PAX4', 'PAX6', 'NEUROG3', 'FEV', 'TPH1', 'GCG', 'CCK', 'PYY', 'SST', 'GIP', 'NTS', 'GHRL', 'SCT', 'MLN', 'GCK', 'PCSK1N'], score_name='EEC_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['CHGB', 'SYP', 'NEUROD1', 'INSM1', 'PAX4', 'PAX6', 'NEUROG3', 'FEV', 'TPH1', 'GCG', 'CCK', 'PYY', 'SST', 'GIP', 'NTS', 'GHRL', 'MLN', 'GCK', 'PCSK1N', 'EEC_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_EEC_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# * Tuft

# %%
sc.tl.score_genes(adata, ['DCLK1', 'TRPM5', 'GFI1B', 'POU2F3', 'LRMP', 'SOX9', 'ALOX5', 'SH2D6', 'PTGS1', 'PLCG2', 'IL25', 'SUCNR1', 'HPGD', 'HCK'], score_name='Tuft_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['DCLK1', 'TRPM5', 'GFI1B', 'POU2F3', 'SOX9', 'SH2D6', 'PTGS1', 'PLCG2', 'IL25', 'SUCNR1', 'HPGD', 'HCK', 'Tuft_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_Tuft_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# + General secretory lineage

# %%
sc.tl.score_genes(adata, ['ATOH1', 'DLL1', 'DLL4', 'NOTCH3', 'SPDEF', 'KLF4', 'XBP1', 'CREB3L1', 'LMAN1'], score_name='secretory_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['ATOH1', 'DLL4', 'NOTCH3', 'SPDEF', 'KLF4', 'XBP1', 'CREB3L1', 'LMAN1', 'secretory_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_secretory_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# + General absorptive score

# %%
sc.tl.score_genes(adata, ['HES1', 'HNF4A', 'CDX2', 'ALPI', 'VIL1', 'APOA1', 'SLC2A2', 'FABP1', 'FABP2', 'SLC15A1'], score_name='absorptive_score')

# %%
fig = plt.figure(figsize=(1, 3), dpi=300)
sc.pl.umap(adata,color=['HES1', 'HNF4A', 'CDX2', 'ALPI', 'VIL1', 'APOA1', 'SLC2A2', 'FABP1', 'FABP2', 'SLC15A1', 'absorptive_score'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
plt.savefig(f"/Users/annamaguza/Desktop/Repos/Fetal_stem_cells_analysis/1_fetalSC_subpoulations/figures/fetalSC_absorptive_signatures_{timestamp}.png", bbox_inches="tight")

# %% [markdown]
# ## Extract signatures

# %%
adata = sc.read_h5ad('/Users/annamaguza/Desktop/data/gut_data/gut_hs_fetal_AM_06032025_142621_raw_velocity.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 317530 × 43704
# ...

# %%
del adata.layers

# %%
adata.obs['cell_states'] = adata.obs['cell_states'].astype('str') + '_' + adata.obs['leiden_cluster'].astype('str')
adata.obs['cell_states'] = adata.obs['cell_states'].str.replace(r'_nan', '', regex=True)
adata.obs['cell_states'] = adata.obs['cell_states'].astype('category')

# %%
sc.pp.normalize_total(adata, target_sum=1e6, exclude_highly_expressed=True)
sc.pp.log1p(adata)

# %%
sc.tl.rank_genes_groups(adata, groupby = 'cell_states', method = 'wilcoxon', n_genes = 100)
sc.pl.rank_genes_groups(adata, n_genes = 25)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/annamaguza/Library/Application Support/hatch/env/virtual/single-cell-project/0fJ3OPid/single_cell_project/lib/python3.11/site-packages/scanpy/tools/_rank_genes_groups.py:435: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# ...

# %%
df = sc.get.rank_genes_groups_df(adata, group = None)

# %%
df.to_csv(f'/Users/annamaguza/Desktop/data/gut_data/fetal_stem_cells_states_vs_other_fetal_DEGs.csv')
