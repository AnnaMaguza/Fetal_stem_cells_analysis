# %% [markdown]
# # Regulatory Network Analysis of adult Stem Cells using scPRINT
#
# * **Author**: Anna Maguza
# * **Location**: CellZome, GSK company
# * **Creation date**: 20.08.2025
# * **Last modified date**: 04.09.2025

# %%
from huggingface_hub import hf_hub_download

from scprint import scPrint
from scdataloader import Preprocessor, utils
from scdataloader.preprocess import additional_preprocess
from scdataloader.utils import load_genes
from scprint.tasks import GNInfer
from grnndata import utils as grnutils
from grnndata import read_h5ad

import lamindb as ln
import scanpy as sc
import numpy as np
from pybiomart import Dataset
from matplotlib import pyplot as plt
import pandas as pd
import json
from anndata.utils import make_index_unique

import gseapy as gp
from gseapy import dotplot
from pyvis import network as pnx
import networkx as nx
import scipy.sparse

# %load_ext autoreload
# %autoreload 2 

import torch
torch.set_float32_matmul_precision('medium')

import os
import ssl
import urllib3
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Preprocessing

# %%
adata = sc.read_h5ad("gut_data/gut_hs_full_annotated_AM_06032025_140458_raw.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 365542 × 43704
#     obs: 'cell_index', 'Source Name', 'ENA_SAMPLE', 'BioSD_SAMPLE', 'organism', 'disease', 'organism_part', 'cell_type', 'growth_condition', 'developmental_stage', 'Material Type', 'Protocol REF', 'sample_id', 'LIBRARY_LAYOUT', 'cdna_read_size', 'cell_barcode_size', 'end_bias', 'library_construction', 'sample_barcode_size', 'umi_barcode_offset', 'umi_barcode_size', 'Performer', 'Assay Name', 'ENA_EXPERIMENT', 'ENA_RUN', 'time', 'time_unit', 'n_genes', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'cell_passed_qc', 'qc_cluster', 'cluster_passed_qc', 'consensus_fraction', 'consensus_passed_qc', 'total_counts', 'n_genes_by_counts', 'percent_chrY', 'XIST-counts', 'XIST-percentage', 'sex', 'S_score', 'G2M_score', 'Cell_cycle_phase', 'Study_name', 'ArrayExpress_ID', 'library_preparation_protocol', 'full_age', 'age_group', 'immunophenotype', 'metadata_cluster', 'barcode', 'category', 'Integrated_05', 'age', 'gestational_age', 'donor_id', 'passage', 'batch', 'sampling_site', 'celltype', 'library_construnction_and_layout', 'cell_states', 'cellstates_scANVI', 'confidence_score', 'gut_region', 'cell_state'
#     uns: 'Cell_cycle_phase_colors', 'Material Type_colors', 'Study_name_colors', '_scvi_manager_uuid', '_scvi_uuid', 'cell_passed_qc_colors', 'consensus_passed_qc_colors', 'hvg', 'library_preparation_protocol_colors', 'metadata_cluster_colors', 'neighbors', 'predicted_doublets_colors', 'processing_history', 'sampling_site_colors', 'sex_colors', 'umap'
#     obsm: 'X_pca', 'X_scANVI', 'X_scVI', 'X_umap', 'umap_uncorrected'

# %%
adult_mask = ["adult", "child stage"]
adata = adata[adata.obs["age_group"].isin(adult_mask)]

# %%
adata.obs["age_group"].value_counts()
# Out:
# age_group
# child stage    16712
# adult          10767
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                                                                                            cell_index  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701           AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701           ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701           CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701           CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701           CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701
# ...                                                                                               ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR9...
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR9...
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR9...
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR9...
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR9...
#
#                                                                Source Name  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                T024_IL_cells
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                T024_IL_cells
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                T024_IL_cells
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                T024_IL_cells
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                T024_IL_cells
# ...                                                                    ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
#
#                                                      ENA_SAMPLE  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701        ERS4414967
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701        ERS4414967
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701        ERS4414967
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701        ERS4414967
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701        ERS4414967
# ...                                                         ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  ERS12382614
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  ERS12382614
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  ERS12382614
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  ERS12382614
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  ERS12382614
#
#                                                       BioSD_SAMPLE  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701         SAMEA6655498
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701         SAMEA6655498
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701         SAMEA6655498
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701         SAMEA6655498
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701         SAMEA6655498
# ...                                                            ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  SAMEA110285004
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  SAMEA110285004
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  SAMEA110285004
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  SAMEA110285004
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  SAMEA110285004
#
#                                                         organism disease  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701       Homo sapiens  normal
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701       Homo sapiens  normal
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701       Homo sapiens  normal
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701       Homo sapiens  normal
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701       Homo sapiens  normal
# ...                                                          ...     ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  Homo sapiens  normal
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  Homo sapiens  normal
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  Homo sapiens  normal
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  Homo sapiens  normal
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  Homo sapiens  normal
#
#                                                      organism_part  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701       terminal ileum
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701       terminal ileum
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701       terminal ileum
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701       terminal ileum
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701       terminal ileum
# ...                                                            ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...        appendix
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...        appendix
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...        appendix
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...        appendix
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...        appendix
#
#                                                         cell_type  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701            unsorted
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701            unsorted
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701            unsorted
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701            unsorted
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701            unsorted
# ...                                                           ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  CD45 positive
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  CD45 positive
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  CD45 positive
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  CD45 positive
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  CD45 positive
#
#                                                    growth_condition  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701        primary tissue
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701        primary tissue
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701        primary tissue
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701        primary tissue
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701        primary tissue
# ...                                                             ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...   primary tissue
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...   primary tissue
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...   primary tissue
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...   primary tissue
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...   primary tissue
#
#                                                    developmental_stage  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701              child stage
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701              child stage
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701              child stage
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701              child stage
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701              child stage
# ...                                                                ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...               adult
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...               adult
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...               adult
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...               adult
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...               adult
#
#                                                     Material Type  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                cell
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                cell
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                cell
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                cell
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                cell
# ...                                                           ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  organism part
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  organism part
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  organism part
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  organism part
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  organism part
#
#                                                      Protocol REF  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701             Unknown
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701             Unknown
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701             Unknown
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701             Unknown
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701             Unknown
# ...                                                           ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  P-MTAB-100978
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  P-MTAB-100978
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  P-MTAB-100978
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  P-MTAB-100978
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  P-MTAB-100978
#
#                                                                  sample_id  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                T024_IL_cells
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                T024_IL_cells
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                T024_IL_cells
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                T024_IL_cells
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                T024_IL_cells
# ...                                                                    ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
#
#                                                    LIBRARY_LAYOUT  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701              PAIRED
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701              PAIRED
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701              PAIRED
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701              PAIRED
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701              PAIRED
# ...                                                           ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...         PAIRED
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...         PAIRED
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...         PAIRED
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...         PAIRED
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...         PAIRED
#
#                                                     cdna_read_size  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                   98
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                   98
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                   98
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                   98
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                   98
# ...                                                            ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...              98
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...              98
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...              98
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...              98
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...              98
#
#                                                     cell_barcode_size  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                      16
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                      16
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                      16
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                      16
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                      16
# ...                                                               ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                 16
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                 16
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                 16
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                 16
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                 16
#
#                                                        end_bias  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701       3 prime tag
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701       3 prime tag
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701       3 prime tag
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701       3 prime tag
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701       3 prime tag
# ...                                                         ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  5 prime tag
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  5 prime tag
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  5 prime tag
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  5 prime tag
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  5 prime tag
#
#                                                    library_construction  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                     10xV2
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                     10xV2
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                     10xV2
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                     10xV2
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                     10xV2
# ...                                                                 ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                10xV2
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                10xV2
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                10xV2
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                10xV2
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                10xV2
#
#                                                     sample_barcode_size  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                         8
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                         8
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                         8
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                         8
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                         8
# ...                                                                 ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                    8
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                    8
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                    8
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                    8
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                    8
#
#                                                     umi_barcode_offset  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                       16
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                       16
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                       16
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                       16
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                       16
# ...                                                                ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                  16
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                  16
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                  16
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                  16
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                  16
#
#                                                     umi_barcode_size  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                     10
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                     10
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                     10
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                     10
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                     10
# ...                                                              ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                10
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                10
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                10
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                10
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                10
#
#                                                                                             Performer  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                               Wellcome Sanger Institute
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                               Wellcome Sanger Institute
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                               Wellcome Sanger Institute
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                               Wellcome Sanger Institute
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                               Wellcome Sanger Institute
# ...                                                                                               ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  Wellcome Sanger Institute Cellular Generation ...
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  Wellcome Sanger Institute Cellular Generation ...
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  Wellcome Sanger Institute Cellular Generation ...
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  Wellcome Sanger Institute Cellular Generation ...
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  Wellcome Sanger Institute Cellular Generation ...
#
#                                                                 Assay Name  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                T024_IL_cells
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                T024_IL_cells
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                T024_IL_cells
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                T024_IL_cells
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                T024_IL_cells
# ...                                                                    ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
#
#                                                    ENA_EXPERIMENT     ENA_RUN  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701          ERX4012101  ERR4010701
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701          ERX4012101  ERR4010701
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701          ERX4012101  ERR4010701
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701          ERX4012101  ERR4010701
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701          ERX4012101  ERR4010701
# ...                                                           ...         ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...     ERX9467979  ERR9924286
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...     ERX9467979  ERR9924286
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...     ERX9467979  ERR9924286
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...     ERX9467979  ERR9924286
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...     ERX9467979  ERR9924286
#
#                                                    time time_unit  n_genes  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701       N/A      year      760
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701       N/A      year     2877
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701       N/A      year     1275
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701       N/A      year     1265
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701       N/A      year      247
# ...                                                 ...       ...      ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  N/A      year      304
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  N/A      year      492
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  N/A      year      441
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  N/A      year      224
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  N/A      year      286
#
#                                                     doublet_scores  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701             0.079821
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701             0.176829
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701             0.204082
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701             0.176829
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701             0.114094
# ...                                                            ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...        0.164087
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...        0.266968
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...        0.133690
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...        0.092437
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...        0.164087
#
#                                                    predicted_doublets  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                   False
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                   False
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                   False
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                   False
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                   False
# ...                                                               ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...              False
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...              False
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...              False
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...              False
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...              False
#
#                                                     n_counts  log1p_n_counts  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701           2209        7.700748
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701          12210        9.410092
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701           4679        8.451053
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701           4172        8.336390
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701            671        6.510258
# ...                                                      ...             ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...       747        6.617403
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...      1235        7.119636
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...      1072        6.978214
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...       660        6.493754
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...       841        6.735780
#
#                                                     log1p_n_genes  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701            6.634633
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701            7.964851
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701            7.151485
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701            7.143618
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701            5.513429
# ...                                                           ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...       5.720312
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...       6.200509
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...       6.091310
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...       5.416100
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...       5.659482
#
#                                                     percent_mito  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701           2.535084
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701          12.440622
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701          15.110066
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701           9.204219
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701           7.004471
# ...                                                          ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...      7.228916
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...     21.619433
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...      2.891791
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...      4.545455
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...      3.448276
#
#                                                     n_counts_mito  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                56.0
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701              1519.0
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701               707.0
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701               384.0
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                47.0
# ...                                                           ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...           54.0
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...          267.0
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...           31.0
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...           30.0
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...           29.0
#
#                                                     percent_ribo  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701          21.276596
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701          29.221949
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701          36.118829
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701          41.706616
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701          54.098361
# ...                                                          ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...      3.614458
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...      0.404858
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...      1.958955
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...      2.424242
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...      3.567182
#
#                                                     n_counts_ribo  percent_hb  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701               470.0         0.0
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701              3568.0         0.0
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701              1690.0         0.0
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701              1740.0         0.0
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701               363.0         0.0
# ...                                                           ...         ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...           27.0         0.0
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...            5.0         0.0
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...           21.0         0.0
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...           16.0         0.0
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...           30.0         0.0
#
#                                                     n_counts_hb  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701               0.0
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701               0.0
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701               0.0
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701               0.0
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701               0.0
# ...                                                         ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...          0.0
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...          0.0
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...          0.0
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...          0.0
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...          0.0
#
#                                                     percent_top50  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701           44.409235
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701           37.805078
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701           47.467408
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701           43.432407
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701           60.059613
# ...                                                           ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...      59.170013
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...      42.348178
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...      50.559701
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...      66.212121
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...      62.663496
#
#                                                     cell_passed_qc qc_cluster  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                 True         38
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                 True          8
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                False         38
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                 True          3
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                False         34
# ...                                                            ...        ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...           False        nan
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...           False        nan
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...            True        nan
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...           False        nan
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...           False        nan
#
#                                                    cluster_passed_qc  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                  False
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                   True
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                  False
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                   True
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                  False
# ...                                                              ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...              <NA>
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...              <NA>
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...              <NA>
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...              <NA>
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...              <NA>
#
#                                                    consensus_fraction  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                     0.6
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                     0.9
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                     0.7
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                     1.0
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                     0.7
# ...                                                               ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                nan
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                nan
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                nan
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                nan
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                nan
#
#                                                    consensus_passed_qc  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                     True
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                     True
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                     True
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                     True
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                     True
# ...                                                                ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                <NA>
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                <NA>
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                <NA>
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                <NA>
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                <NA>
#
#                                                     total_counts  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701               2209
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701              12210
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701               4679
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701               4172
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                671
# ...                                                          ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...           747
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...          1235
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...          1072
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...           660
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...           841
#
#                                                     n_genes_by_counts  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                     760
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                    2877
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                    1275
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                    1265
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                     247
# ...                                                               ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                304
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                492
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                441
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                224
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                286
#
#                                                     percent_chrY  XIST-counts  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701           0.000000            0
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701           0.000000            0
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701           0.000000            0
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701           0.000000            0
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701           0.000000            0
# ...                                                          ...          ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...      0.000000            0
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...      0.000000            0
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...      0.093284            0
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...      0.000000            0
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...      0.000000            0
#
#                                                     XIST-percentage     sex  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                   0.0  female
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                   0.0  female
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                   0.0  female
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                   0.0  female
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                   0.0  female
# ...                                                             ...     ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...              0.0    male
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...              0.0    male
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...              0.0    male
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...              0.0    male
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...              0.0    male
#
#                                                      S_score  G2M_score  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701      -0.220265  -0.244333
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701       1.216646  -0.303158
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701      -0.285024  -0.508144
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701      -0.100596  -0.255890
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701      -0.117381  -0.123526
# ...                                                      ...        ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99... -0.026490  -0.082350
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99... -0.102831   0.198631
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99... -0.074943  -0.105500
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  0.000000  -0.065141
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  0.000000   0.128947
#
#                                                    Cell_cycle_phase  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                    G1
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                     S
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                    G1
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                    G1
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                    G1
# ...                                                             ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...               G1
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...              G2M
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...               G1
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                S
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...              G2M
#
#                                                           Study_name  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701       Elementaite_2021
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701       Elementaite_2021
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701       Elementaite_2021
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701       Elementaite_2021
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701       Elementaite_2021
# ...                                                              ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  Elementaite_2021
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  Elementaite_2021
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  Elementaite_2021
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  Elementaite_2021
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  Elementaite_2021
#
#                                                    ArrayExpress_ID  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701          E-MTAB-8901
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701          E-MTAB-8901
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701          E-MTAB-8901
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701          E-MTAB-8901
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701          E-MTAB-8901
# ...                                                            ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...     E-MTAB-9543
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...     E-MTAB-9543
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...     E-MTAB-9543
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...     E-MTAB-9543
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...     E-MTAB-9543
#
#                                                    library_preparation_protocol  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                 10xV2 3 prime tag
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                 10xV2 3 prime tag
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                 10xV2 3 prime tag
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                 10xV2 3 prime tag
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                 10xV2 3 prime tag
# ...                                                                         ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...            10xV2 5 prime tag
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...            10xV2 5 prime tag
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...            10xV2 5 prime tag
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...            10xV2 5 prime tag
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...            10xV2 5 prime tag
#
#                                                          full_age  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701             12 year
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701             12 year
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701             12 year
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701             12 year
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701             12 year
# ...                                                           ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  25 to 30 year
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  25 to 30 year
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  25 to 30 year
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  25 to 30 year
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  25 to 30 year
#
#                                                       age_group  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701       child stage
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701       child stage
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701       child stage
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701       child stage
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701       child stage
# ...                                                         ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...        adult
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...        adult
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...        adult
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...        adult
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...        adult
#
#                                                    immunophenotype  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701          total cells
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701          total cells
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701          total cells
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701          total cells
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701          total cells
# ...                                                            ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...   CD45 positive
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...   CD45 positive
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...   CD45 positive
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...   CD45 positive
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...   CD45 positive
#
#                                                    metadata_cluster  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                     0
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                     0
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                     0
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                     0
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                     0
# ...                                                             ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                2
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                2
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                2
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                2
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                2
#
#                                                              barcode  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701       AAACGGGGTCTTGTCC
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701       ACTGATGTCTAACTGG
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701       CATATTCGTCAGATAA
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701       CATGCCTTCAACTCTT
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701       CGACCTTAGTCCGTAT
# ...                                                              ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  CTACCCACACAACGTT
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  CTGTTTATCACTATTC
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  GCAATCAAGACTAGAT
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  TGACGGCAGGTGACCA
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  TGTGTTTTCGGCCGAT
#
#                                                        category  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701           Unknown
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701        Epithelial
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701           Unknown
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701           Unknown
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701           Unknown
# ...                                                         ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  Endothelial
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...      Unknown
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  Endothelial
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  Endothelial
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  Endothelial
#
#                                                        Integrated_05  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                Unknown
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                     TA
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                Unknown
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                Unknown
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                Unknown
# ...                                                              ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  Mature venous EC
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...           Unknown
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...    LEC5 (CLDN11+)
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  Mature venous EC
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  Mature venous EC
#
#                                                          age  gestational_age  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701             12  N/A - not fetal
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701             12  N/A - not fetal
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701             12  N/A - not fetal
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701             12  N/A - not fetal
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701             12  N/A - not fetal
# ...                                                      ...              ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  25 to 30  N/A - not fetal
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  25 to 30  N/A - not fetal
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  25 to 30  N/A - not fetal
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  25 to 30  N/A - not fetal
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  25 to 30  N/A - not fetal
#
#                                                    donor_id passage  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701          T024     N/A
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701          T024     N/A
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701          T024     N/A
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701          T024     N/A
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701          T024     N/A
# ...                                                     ...     ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...     411C     N/A
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...     411C     N/A
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...     411C     N/A
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...     411C     N/A
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...     411C     N/A
#
#                                                                      batch  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701              4918STDY7274839
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701              4918STDY7274839
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701              4918STDY7274839
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701              4918STDY7274839
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701              4918STDY7274839
# ...                                                                    ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  Human_colon_16S8159192
#
#                                                    sampling_site     celltype  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701            unknown   Epithelial
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701            unknown   Epithelial
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701            unknown   Epithelial
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701            unknown   Epithelial
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701            unknown   Epithelial
# ...                                                          ...          ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...       unknown  Endothelial
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...       unknown  Endothelial
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...       unknown  Endothelial
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...       unknown  Endothelial
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...       unknown  Endothelial
#
#                                                    library_construnction_and_layout  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701                          10xV2_PAIRED
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                          10xV2_PAIRED
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701                          10xV2_PAIRED
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701                          10xV2_PAIRED
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701                          10xV2_PAIRED
# ...                                                                             ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...                     10xV2_PAIRED
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...                     10xV2_PAIRED
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                     10xV2_PAIRED
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...                     10xV2_PAIRED
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...                     10xV2_PAIRED
#
#                                                            cell_states  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701               Enterocyte
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                       TA
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701       mature Goblet cell
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701       mature Goblet cell
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701       mature Goblet cell
# ...                                                                ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...           Venous EC
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...         Arterial EC
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...                 LEC
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...           Venous EC
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...           Venous EC
#
#                                                    cellstates_scANVI  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701             Enterocyte
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701                     TA
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701            Goblet cell
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701            Goblet cell
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701            Goblet cell
# ...                                                              ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...         Venous EC
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...       Arterial EC
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...               LEC
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...         Venous EC
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...         Venous EC
#
#                                                     confidence_score  \
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701               0.881713
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701               0.970722
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701               0.999956
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701               0.999979
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701               0.997301
# ...                                                              ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...          0.999987
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...          0.998362
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...          0.999995
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...          0.999944
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...          0.999997
#
#                                                          gut_region cell_state
# cell_index
# AAACGGGGTCTTGTCC-1-4918STDY7274839_ERR4010701       small intestine        NaN
# ACTGATGTCTAACTGG-1-4918STDY7274839_ERR4010701       small intestine        NaN
# CATATTCGTCAGATAA-1-4918STDY7274839_ERR4010701       small intestine        NaN
# CATGCCTTCAACTCTT-1-4918STDY7274839_ERR4010701       small intestine        NaN
# CGACCTTAGTCCGTAT-1-4918STDY7274839_ERR4010701       small intestine        NaN
# ...                                                             ...        ...
# CTACCCACACAACGTT-1-Human_colon_16S8159192_ERR99...  large intestine  Venous EC
# CTGTTTATCACTATTC-1-Human_colon_16S8159192_ERR99...  large intestine    Unknown
# GCAATCAAGACTAGAT-1-Human_colon_16S8159192_ERR99...  large intestine        LEC
# TGACGGCAGGTGACCA-1-Human_colon_16S8159192_ERR99...  large intestine  Venous EC
# TGTGTTTTCGGCCGAT-1-Human_colon_16S8159192_ERR99...  large intestine  Venous EC
#
# [27479 rows x 77 columns]

# %% [markdown]
# ### Load ontology mapping file

# %%
with open('ontology_terms.json', 'r') as f:
    ontology_data = json.load(f)

cell_type_mapping = {item['cell_annotation']: item['ontology_term'] 
                     for item in ontology_data['ontology_terms']}
tissue_mapping = {item['tissue']: item['ontology_term'] 
                  for item in ontology_data['tissue_mapping']}
sex_mapping = ontology_data['sex_mapping']
age_group_mapping = ontology_data['age_group_mapping']
assay_mapping = ontology_data['assay_mapping']

# %%
adata.obs['organism'] = 'Homo sapiens'
adata.obs['organism_ontology_term_id'] = 'NCBITaxon:9606'

# %%
# Map cell_states to cell_type_ontology_term_id
adata.obs['cell_type_ontology_term_id'] = 'unknown'
for cell_type in adata.obs['cell_states'].unique():
    if cell_type in cell_type_mapping:
        ontology_id = cell_type_mapping[cell_type]
        mask = adata.obs['cell_states'] == cell_type
        adata.obs.loc[mask, 'cell_type_ontology_term_id'] = ontology_id
    else:
        print(f"No mapping found for '{cell_type}', keeping as 'unknown'")

# %%
# Map age_group to development_stage_ontology_term_id
adata.obs['development_stage_ontology_term_id'] = adata.obs['age_group'].map(age_group_mapping)

# %%
# Map gut_region to tissue_ontology_term_id 
if 'gut_region' in adata.obs.columns:
    adata.obs['tissue_ontology_term_id'] = adata.obs['gut_region'].map(tissue_mapping)
else:
    adata.obs['tissue_ontology_term_id'] = 'unknown'

# %%
# Map sex to sex_ontology_term_id 
if 'sex' in adata.obs.columns:
    # Convert to string to handle categorical issues
    adata.obs['sex_normalized'] = adata.obs['sex'].astype(str).str.lower()
    adata.obs['sex_ontology_term_id'] = adata.obs['sex_normalized'].map(sex_mapping).fillna('unknown')
    adata.obs.drop('sex_normalized', axis=1, inplace=True)
else:
    adata.obs['sex_ontology_term_id'] = 'unknown'

# %%
# Map library_preparation_protocol to assay_ontology_term_id
protocol_str = adata.obs['library_preparation_protocol'].astype(str)
adata.obs['assay_ontology_term_id'] = protocol_str.map(assay_mapping).fillna('EFO:0008913')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = 'unknown'
adata.obs['disease_ontology_term_id'] = 'PATO:0000461'  # normal

# %%
required_cols = ['organism_ontology_term_id', 'cell_type_ontology_term_id', 'tissue_ontology_term_id', 
                'assay_ontology_term_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id',
                'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id']
missing_cols = [col for col in required_cols if col not in adata.obs.columns]
print(f"WARNING: Missing required columns: {missing_cols}")
# Out:
# WARNING: Missing required columns: []

# %%
adata.var["gene_symbol"] = adata.var.index.copy()

# %%
adata.var
# Out:
#                      gene_symbol
# WASH7P                    WASH7P
# ENSG00000238009  ENSG00000238009
# CICP27                    CICP27
# ENSG00000268903  ENSG00000268903
# ENSG00000269981  ENSG00000269981
# ...                          ...
# ENSG00000277836  ENSG00000277836
# ENSG00000278633  ENSG00000278633
# ENSG00000276017  ENSG00000276017
# ENSG00000278817  ENSG00000278817
# ENSG00000277196  ENSG00000277196
#
# [43704 rows x 1 columns]

# %%
dataset = Dataset(name='hsapiens_gene_ensembl', host='http://www.ensembl.org')

# %%
biomart_results = dataset.query(attributes=['ensembl_gene_id', 'external_gene_name'])

# %%
biomart_results
# Out:
#         Gene stable ID Gene name
# 0      ENSG00000210049     MT-TF
# 1      ENSG00000211459   MT-RNR1
# 2      ENSG00000210077     MT-TV
# 3      ENSG00000210082   MT-RNR2
# 4      ENSG00000209082    MT-TL1
# ...                ...       ...
# 86364  ENSG00000168710    AHCYL1
# 86365  ENSG00000081692     JMJD4
# 86366  ENSG00000157873  TNFRSF14
# 86367  ENSG00000132676      DAP3
# 86368  ENSG00000163374    YY1AP1
#
# [86369 rows x 2 columns]

# %%
adata.var
# Out:
#                      gene_symbol
# WASH7P                    WASH7P
# ENSG00000238009  ENSG00000238009
# CICP27                    CICP27
# ENSG00000268903  ENSG00000268903
# ENSG00000269981  ENSG00000269981
# ...                          ...
# ENSG00000277836  ENSG00000277836
# ENSG00000278633  ENSG00000278633
# ENSG00000276017  ENSG00000276017
# ENSG00000278817  ENSG00000278817
# ENSG00000277196  ENSG00000277196
#
# [43704 rows x 1 columns]

# %%
# Create a mapping dictionary from biomart_results
gene_id_map = biomart_results.set_index('Gene name')['Gene stable ID'].to_dict()

# Add ensembl gene IDs to adata.var
adata.var['gene_id-query'] = adata.var['gene_symbol'].map(gene_id_map)

# Fill missing values with the corresponding index values
adata.var['gene_id-query'] = adata.var['gene_id-query'].fillna(adata.var.index.to_series())

# %%
adata.var.index = adata.var['gene_id-query'].copy()

# %%
# Check for duplicates in var index
duplicates = adata.var.index.duplicated()
duplicates
# Out:
# array([False, False, False, ..., False, False, False])

# %%
adata.var
# Out:
#                      gene_symbol    gene_id-query
# gene_id-query
# ENSG00000310526           WASH7P  ENSG00000310526
# ENSG00000238009  ENSG00000238009  ENSG00000238009
# ENSG00000233750           CICP27  ENSG00000233750
# ENSG00000268903  ENSG00000268903  ENSG00000268903
# ENSG00000269981  ENSG00000269981  ENSG00000269981
# ...                          ...              ...
# ENSG00000277836  ENSG00000277836  ENSG00000277836
# ENSG00000278633  ENSG00000278633  ENSG00000278633
# ENSG00000276017  ENSG00000276017  ENSG00000276017
# ENSG00000278817  ENSG00000278817  ENSG00000278817
# ENSG00000277196  ENSG00000277196  ENSG00000277196
#
# [43704 rows x 2 columns]

# %%
if adata.var.index.duplicated().any():
    adata = adata[:, ~adata.var.index.duplicated(keep='first')]

# %% [markdown]
# ### Preprocessor module
# scPRINT converts the gene expression of a cell to an embedding by summing three representations or tokens: its id, expression, and genomic location scdataloader. The Preprocessor module specifically handles:
#
# Gene ID Encoding: scPRINT encodes the gene IDs using protein embeddings. This gene representation is made using the ESM2 amino-acid embedding of its most common protein product.
# Expression Embedding: The gene's expression is tokenized via a multi-layer perceptron (MLP) using log-normalized counts. This MLP lets the model learn a metric behind gene expression.
# Positional Encoding: We help the model know that genes with similar locations tend to be regulated by identical DNA regions, using the positional encoding of their location in the genome.
#
# The preprocessor makes sure that the fields are all here, the genes are in the right format, the raw counts are used.

# %%
preprocessor = Preprocessor(
    do_postp=True, # takes too much RAM in collab to do PCA
    # additional_postprocess=additional_postprocess,
    additional_preprocess=additional_preprocess,
    force_preprocess=True,
)

# %%
adata.var.index = adata.var["gene_id-query"].astype(str).copy()

# %%
adata = preprocessor(adata)
# Out:
# Dropping layers:  KeysView(Layers with keys: )
# checking raw counts
# removed 0 non primary cells, 27479 renamining
# filtered out 1495 cells, 25984 renamining
# Removed 1403 genes not known to the ontology
# Removed 0 duplicate genes
# Added 28325 genes in the ontology but not present in the dataset
# validating
# /Users/am336941/uv_envs/scprint_env230/scprint_env230/lib/python3.10/site-packages/scdataloader/preprocess.py:287: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   adata, organism=adata.obs.organism_ontology_term_id[0], need_all=False
# starting QC
# Seeing 12099 outliers (46.56% of total dataset):
# normalize
# starting PCA
# done
# AnnData object with n_obs × n_vars = 25984 × 70611
#     obs: 'cell_index', 'Source Name', 'ENA_SAMPLE', 'BioSD_SAMPLE', 'organism', 'disease', 'organism_part', 'cell_type', 'growth_condition', 'developmental_stage', 'Material Type', 'Protocol REF', 'sample_id', 'LIBRARY_LAYOUT', 'cdna_read_size', 'cell_barcode_size', 'end_bias', 'library_construction', 'sample_barcode_size', 'umi_barcode_offset', 'umi_barcode_size', 'Performer', 'Assay Name', 'ENA_EXPERIMENT', 'ENA_RUN', 'time', 'time_unit', 'n_genes', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'cell_passed_qc', 'qc_cluster', 'cluster_passed_qc', 'consensus_fraction', 'consensus_passed_qc', 'total_counts', 'n_genes_by_counts', 'percent_chrY', 'XIST-counts', 'XIST-percentage', 'sex', 'S_score', 'G2M_score', 'Cell_cycle_phase', 'Study_name', 'ArrayExpress_ID', 'library_preparation_protocol', 'full_age', 'age_group', 'immunophenotype', 'metadata_cluster', 'barcode', 'category', 'Integrated_05', 'age', 'gestational_age', 'donor_id', 'passage', 'batch', 'sampling_site', 'celltype', 'library_construnction_and_layout', 'cell_states', 'cellstates_scANVI', 'confidence_score', 'gut_region', 'cell_state', 'organism_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'assay_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id', 'cell_culture', 'nnz', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'outlier', 'mt_outlier', 'batches'
#     var: 'gene_symbol', 'gene_id-query', 'uid', 'symbol', 'biotype', 'organism_id', 'mt', 'ribo', 'hb', 'organism', 'ensembl_gene_id', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'unseen_genes'
#     obsm: 'X_pca'
#     layers: 'norm'

# %%
file = ln.Artifact.from_anndata(adata, description="test anndata")
file.save()
col = ln.Collection(file, name="test")
col.save()
# Out:
# ! no run & transform got linked, call `ln.track()` & re-run
# ... storing 'organism' as categorical
# ... storing 'organism_ontology_term_id' as categorical
# ... storing 'cell_type_ontology_term_id' as categorical
# ... storing 'sex_ontology_term_id' as categorical
# ... storing 'assay_ontology_term_id' as categorical
# ... storing 'self_reported_ethnicity_ontology_term_id' as categorical
# ... storing 'disease_ontology_term_id' as categorical
# ... storing 'cell_culture' as categorical
# ... storing 'batches' as categorical
# ... storing 'gene_symbol' as categorical
# ... storing 'gene_id-query' as categorical
# ... storing 'symbol' as categorical
# ... storing 'biotype' as categorical
# ... storing 'organism' as categorical
# ! no run & transform got linked, call `ln.track()` & re-run
# ! run input wasn't tracked, call `ln.track()` and re-run
# /var/folders/8j/syfvxwvd4lggpmnnpd_r8jkr0000gp/T/ipykernel_21614/1650442001.py:3: FutureWarning: argument `name` will be removed, please pass test to `key` instead
#   col = ln.Collection(file, name="test")
# Collection(uid='t8jDRJB9T6t2f90x0000', is_latest=True, key='test', hash='0wQFw47QjaNdjX_3NazIOg', created_by_id=1, space_id=1, created_at=2025-09-15 04:15:56 UTC)

# %% [markdown]
# ### Loading the model

# %%
# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Set environment variables to disable SSL verification
os.environ['PYTHONHTTPSVERIFY'] = '0'
os.environ['CURL_CA_BUNDLE'] = ''
os.environ['REQUESTS_CA_BUNDLE'] = ''
os.environ['SSL_VERIFY'] = 'false'

# Configure SSL context
ssl._create_default_https_context = ssl._create_unverified_context

# Configure requests to not verify SSL
import requests.packages.urllib3.util.ssl_
requests.packages.urllib3.util.ssl_.DEFAULT_CIPHERS = 'ALL'

# Monkey patch requests to disable SSL verification
original_request = requests.Session.request
def patched_request(self, method, url, **kwargs):
    kwargs['verify'] = False
    return original_request(self, method, url, **kwargs)
requests.Session.request = patched_request

# Now download the model
model_checkpoint_file = hf_hub_download(
    repo_id="jkobject/scPRINT", 
    filename="v2-medium.ckpt"
)

# %%
model_checkpoint_file

# %%
# make sure that you check if you have a GPU with flashattention or not (see README)
try:
    m = torch.load(model_checkpoint_file)
# if not use this instead since the model weights are by default mapped to GPU types
except RuntimeError: 
    m = torch.load(model_checkpoint_file, map_location=torch.device('cpu'))

# %%
# again here by default the model was trained with flash attention, so if you do not have a GPU you will need to replace the attention mechanism with regular attention 
transformer = "flash" if torch.cuda.is_available() else "normal"

# %%
# both are for compatibility issues with different versions of the pretrained model, so we need to load it with the correct transformer
if "prenorm" in m['hyper_parameters']:
    m['hyper_parameters'].pop("prenorm")
    torch.save(m, model_checkpoint_file)
if "label_counts" in m['hyper_parameters']:
    # you need to set precpt_gene_emb=None otherwise the model will look for its precomputed gene embeddings files although they were already converted into model weights, so you don't need this file for a pretrained model
    model = scPrint.load_from_checkpoint(model_checkpoint_file, precpt_gene_emb=None, classes=m['hyper_parameters']['label_counts'], transformer=transformer)
else:
    model = scPrint.load_from_checkpoint(model_checkpoint_file, precpt_gene_emb=None, transformer=transformer)
# Out:
# RuntimeError caught: scPrint is not attached to a `Trainer`.

# %%
# this might happen if you have a model that was trained with a different set of genes than the one you are using in the ontology (e.g. newer ontologies), While having genes in the onlogy not in the model is fine. the opposite is not, so we need to remove the genes that are in the model but not in the ontology
missing = set(model.genes) - set(load_genes(model.organisms).index)
if len(missing) > 0:
    print(
        "Warning: some genes missmatch exist between model and ontology: solving...",
    )
# Out:
# Warning: some genes missmatch exist between model and ontology: solving...

# %%
# again if not on GPU you need to convert the model to float64
if not torch.cuda.is_available():
    model = model.to(torch.float32)
    
# you can perform your inference on float16 if you have a GPU, otherwise use float64
dtype = torch.float16 if torch.cuda.is_available() else torch.float32

# the models are often loaded with some parts still displayed as "cuda" and some as "cpu", so we need to make sure that the model is fully on the right device 
model = model.to("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Download data and filter

# %%
#sc.pp.filter_genes(adata, min_cells=1)

# %%
adata.layers["counts"] = adata.X.copy()

# %%
sc.pp.highly_variable_genes(adata, 
                            n_top_genes=3000, 
                            batch_key="sample_id",
                            layer="counts",
                            flavor="seurat_v3",
                            subset=False,  # Don't subset - just mark highly variable genes
                            span=1)

# Let's see how many highly variable genes we have
print(f"Number of highly variable genes: {adata.var['highly_variable'].sum()}")
print(f"Total genes: {adata.n_vars}")
# Out:
# Number of highly variable genes: 3000
# Total genes: 70611

# %%
# Keep the filtered dataset for GRN inference
print(f"Filtered dataset shape: {adata.shape}")
print(f"Number of highly variable genes: {adata.n_vars}")
# Out:
# Filtered dataset shape: (25984, 70611)
# Number of highly variable genes: 70611

# %% [markdown]
# ### Gene network inference
#
# Finally we will use scPRINT to infer gene networks on another cell of interest, the fibroblasts, in both normal and BPH conditions.

# %% [markdown]
# **• "most var within"**:
#     ◦ Purpose: This method identifies genes that show the highest variability or dispersion in their expression levels within a specified cell type or a homogeneous subset of your data. It aims to capture the intrinsic heterogeneity or dynamic range of gene expression within a particular biological population.
#         ▪ The code first subsets the AnnData object (adata) to only include cells of the cell_type specified (if provided) into subadata.
#         ▪ It then applies sc.pp.highly_variable_genes(subadata, flavor="seurat_v3", n_top_genes=self.num_genes). This function is designed to identify genes that are highly variable within the input data subset (subadata). The seurat_v3 flavor is a common method in single-cell analysis for this purpose.
#         ▪ self.curr_genes is then populated with these identified highly variable genes.
#
# **• "most var across"**:
#     ◦ Purpose: This method identifies genes that are most differentially expressed or show significant variability between different groups or cell types. Its goal is to highlight genes that distinguish one cell type or condition from others, indicating potential drivers of cell identity or disease states.
#         ▪ This option explicitly checks if cell_type is not None, indicating its intention to compare a specific cell type against others (or the rest of the dataset).
#         ▪ It uses sc.tl.rank_genes_groups(adata, ..., groupby=self.cell_type_col, groups=[cell_type]). The rank_genes_groups function is a standard Scanpy tool for differential expression analysis, which inherently calculates genes that are significantly different across the defined groups (in this case, [cell_type] vs. all other cells in adata or other groups if configured).
#         ▪ diff_expr_genes are extracted from the results of this differential expression analysis, representing genes that are highly variable between the cell_type of interest and other cells.
#         ▪ self.curr_genes is then set to these top differentially expressed genes.

# %%
grn_inferer = GNInfer(
                    # here we use the most variable genes - this will automatically select from highly variable genes
                    how="most var across",  # corrected to "most var" based on the actual error message
                    # we will preprocess the attention matrix with softmax
                    preprocess="softmax",
                    # we don't aggregate the heads here, we will do it manually
                    head_agg='mean',
                    # we will not use any filtration here, but you can use "none" or "topk" for top k connections per genes or "thresh" for a defined threshold, and more
                    filtration="thresh",
                    # here if we generate the attention matrices by performing a task, like denoising or by just passing the expression profile through the model
                    forward_mode="none",
                    # use the 3000 highly variable genes
                    num_genes=10000,  # this will select from the marked highly variable genes
                    doplot=True,
                    batch_size=8,
                    cell_type_col = "cell_states",
                    # disable multiprocessing to avoid collator issues
                    num_workers=0,  # set to 0 to avoid multiprocessing errors,
                    dtype=dtype,
                    # list of layers to use
                    layer=list(range(model.nlayers))[:]
                    )

# %%
# Use this dataset for GRN inference
grn_full = grn_inferer(model, adata, cell_type="Stem cells")
# Out:
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# Some valid genes are not in the genedf!!!
# 100%|██████████| 129/129 [41:06<00:00, 19.12s/it]
# /Users/am336941/uv_envs/scprint_env230/scprint_env230/lib/python3.10/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/am336941/uv_envs/scprint_env230/scprint_env230/lib/python3.10/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/am336941/uv_envs/scprint_env230/scprint_env230/lib/python3.10/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/am336941/uv_envs/scprint_env230/scprint_env230/lib/python3.10/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# avg link count: 1677640, sparsity: 0.016746243197786993

# %%
grn_full.var
# Out:
#                      gene_symbol    gene_id-query           uid   symbol  \
# ENSG00000000003           TSPAN6  ENSG00000000003  1uTi9dROoaN5   TSPAN6
# ENSG00000000419             DPM1  ENSG00000000419  4eC1wUNJAO2s     DPM1
# ENSG00000000457            SCYL3  ENSG00000000457  5Zug63FETk4p    SCYL3
# ENSG00000000460            FIRRM  ENSG00000000460  3wEqb6eOTZzC    FIRRM
# ENSG00000001036            FUCA2  ENSG00000001036  5kgAeF5qhzAi    FUCA2
# ...                          ...              ...           ...      ...
# ENSG00000291317          TMEM276  ENSG00000291317  7HpBiaqF8f1Z  TMEM276
# ENSG00000291348            CENPP  ENSG00000291348  461nUGcGAs3o    CENPP
# ENSG00000292226  ENSG00000292226  ENSG00000292226  3EFs0lHhq4OR      NaN
# ENSG00000292227  ENSG00000292227  ENSG00000292227  6wuHEMUOZ3WL      NaN
# ENSG00000292228  ENSG00000292228  ENSG00000292228  3nnji7ZXKwI4      NaN
#
#                         biotype  organism_id     mt   ribo     hb  \
# ENSG00000000003  protein_coding          105  False  False  False
# ENSG00000000419  protein_coding          105  False  False  False
# ENSG00000000457  protein_coding          105  False  False  False
# ENSG00000000460  protein_coding          105  False  False  False
# ENSG00000001036  protein_coding          105  False  False  False
# ...                         ...          ...    ...    ...    ...
# ENSG00000291317  protein_coding          105  False  False  False
# ENSG00000291348  protein_coding          105  False  False  False
# ENSG00000292226  protein_coding          105  False  False  False
# ENSG00000292227  protein_coding          105  False  False  False
# ENSG00000292228  protein_coding          105  False  False  False
#
#                        organism  ensembl_gene_id  n_cells_by_counts  \
# ENSG00000000003  NCBITaxon:9606  ENSG00000000003                618
# ENSG00000000419  NCBITaxon:9606  ENSG00000000419               1990
# ENSG00000000457  NCBITaxon:9606  ENSG00000000457                758
# ENSG00000000460  NCBITaxon:9606  ENSG00000000460                481
# ENSG00000001036  NCBITaxon:9606  ENSG00000001036               1092
# ...                         ...              ...                ...
# ENSG00000291317  NCBITaxon:9606  ENSG00000291317                 87
# ENSG00000291348  NCBITaxon:9606  ENSG00000291348                 15
# ENSG00000292226  NCBITaxon:9606  ENSG00000292226                 31
# ENSG00000292227  NCBITaxon:9606  ENSG00000292227                102
# ENSG00000292228  NCBITaxon:9606  ENSG00000292228                 25
#
#                  mean_counts  log1p_mean_counts  pct_dropout_by_counts  \
# ENSG00000000003     0.035753           0.035128              97.621613
# ENSG00000000419     0.093865           0.089718              92.341441
# ENSG00000000457     0.032097           0.031592              97.082820
# ENSG00000000460     0.021398           0.021172              98.148861
# ENSG00000001036     0.054072           0.052661              95.797414
# ...                      ...                ...                    ...
# ENSG00000291317     0.003387           0.003381              99.665179
# ENSG00000291348     0.000693           0.000692              99.942272
# ENSG00000292226     0.001193           0.001192              99.880696
# ENSG00000292227     0.004079           0.004071              99.607451
# ENSG00000292228     0.001001           0.001000              99.903787
#
#                  total_counts  log1p_total_counts  highly_variable  \
# ENSG00000000003         929.0            6.835185            False
# ENSG00000000419        2439.0            7.799753            False
# ENSG00000000457         834.0            6.727432            False
# ENSG00000000460         556.0            6.322565            False
# ENSG00000001036        1405.0            7.248504            False
# ...                       ...                 ...              ...
# ENSG00000291317          88.0            4.488636            False
# ENSG00000291348          18.0            2.944439            False
# ENSG00000292226          31.0            3.465736            False
# ENSG00000292227         106.0            4.672829            False
# ENSG00000292228          26.0            3.295837            False
#
#                  highly_variable_rank     means  variances  variances_norm  \
# ENSG00000000003                1306.0  0.035753   0.075426        0.713581
# ENSG00000000419                1658.0  0.093865   0.138862        0.729487
# ENSG00000000457                1228.0  0.032097   0.038996        0.753652
# ENSG00000000460                1863.0  0.021398   0.027406        0.768021
# ENSG00000001036                1580.0  0.054072   0.088097        0.693110
# ...                               ...       ...        ...             ...
# ENSG00000291317                1841.0  0.003387   0.003452        0.183966
# ENSG00000291348                1349.5  0.000693   0.000923        0.190690
# ENSG00000292226                   NaN  0.001193   0.001192        0.152374
# ENSG00000292227                1775.0  0.004079   0.004448        0.203714
# ENSG00000292228                2015.0  0.001001   0.001077        0.122853
#
#                  highly_variable_nbatches    TFs
# ENSG00000000003                        21  False
# ENSG00000000419                        13  False
# ENSG00000000457                        10  False
# ENSG00000000460                        11  False
# ENSG00000001036                         9  False
# ...                                   ...    ...
# ENSG00000291317                         1  False
# ENSG00000291348                         2  False
# ENSG00000292226                         0  False
# ENSG00000292227                         2  False
# ENSG00000292228                         1  False
#
# [10000 rows x 24 columns]

# %%
grn_full.write_h5ad("1_scPRINT/data/grn_sc_adult_10K_genes.h5ad")
